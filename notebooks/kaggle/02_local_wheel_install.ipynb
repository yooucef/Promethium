# %% [markdown]
# # Promethium: Offline Wheel Installation
#
# This notebook demonstrates how to install `promethium-seismic` in a **zero-network** environment (like an offline Kaggle competition) using a pre-downloaded wheel file from a Kaggle Dataset.
#
# > **Note:** This requires the `promethium-seismic-wheel-1.0.3` dataset to be attached to your notebook at `../input/promethium-seismic-wheel-100`.
#
# ---

# %% [markdown]
# ## 1. Install from Local Wheel
#
# We use `pip` to install the package from the attached dataset path. This does **not** require internet access.

# %%
# Install from the local wheel file
# IMPORTANT: Adjust the path if the dataset version or filename differs
# !pip install ../input/promethium-seismic-wheel-100/promethium_seismic-1.0.3-py3-none-any.whl

# %% [markdown]
# ## 2. Verify Installation
#
# Once installed, we can import the library normally.

# %%
import promethium

print(f"Successfully imported promethium version: {promethium.__version__}")
print(f"Installation location: {promethium.__file__}")

# %% [markdown]
# ## 3. Run Pipeline
#
# Example usage of the installed library.

# %%
from promethium import SeismicRecoveryPipeline

try:
    pipeline = SeismicRecoveryPipeline.from_preset("unet_denoise_v1")
    print("Pipeline loaded successfully.")
except Exception as e:
    print(f"Pipeline loading failed (expected if weights are missing): {e}")
